# %%
#Pratik Mali
import tweepy
from textblob import TextBlob
from matplotlib import pyplot as plt 
import numpy as np
#Add Consumer Key and Consumer Secret from https://developer.twitter.com
consumer_key = ''
consumer_secret = ''

#Add Access Token and Access Token Secret from https://developer.twitter.com
access_token = ''
access_token_secret = ''

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search('biden')

"""
for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
"""
ptweet=ntweet=neutweet=0
print('TWEETS')
for tweet in public_tweets:
    print("\n",tweet.text)
    analysis = TextBlob(tweet.text)
    if analysis.sentiment.polarity>0:
    	print('Positive')
    	print('******')
    	ptweet += 1

    elif analysis.sentiment.polarity==0:
    	print('Neutral')
    	print('******')
    	neutweet += 1

    else:
    	print('Negative')
    	print('******')
    	ntweet += 1
data=[ptweet, neutweet, ntweet]
ttype=['Positive','Neutral', 'Negative']
print("Positive tweets percentage: {} %".format(100*(ptweet)/len(public_tweets)))

print("Neutral tweets percentage: {} %".format(100*(neutweet)/len(public_tweets)))

print("Negative tweets percentage: {} %".format(100*(ntweet)/len(public_tweets)))

fig = plt.figure(figsize =(5, 5)) 
plt.title('Tweet sentiment')
plt.pie(data, labels = ttype, autopct='%1.2f%%') 
plt.show()
# Out:
# TWEETS
#
#  Trump já perdeu! Pode anotar aí e me cobrar depois. Biden será eleito com uma folga tranquila de delegados e nada a… https://t.co/wAyvLMwVkA
# Neutral
# ******
#
#  RT @rishibagree: Difference between Trump &amp; Biden https://t.co/iTUhf2mnlW
# Neutral
# ******
#
#  @BooomShakaBooom Biden
# Neutral
# ******
#
#  Hunter Biden Finger Lakes Info, New Seth Rich Docs Coming https://t.co/fYstjh3IkV via @BitChute
# Positive
# ******
#
#  RT @shaun_vids: biden wins by an unarguable margin, team trump declares victory anyway and dares the democrats to do anything about it, the…
# Positive
# ******
#
#  RT @drugproblem: Another reason to vote for Biden 🤝
# Neutral
# ******
#
#  Elecciones en Estados Unidos 2020: qué pasará con México si gana Trump, si gana Biden y cuál sería el peor escenari… https://t.co/g4EuTnlYOq
# Neutral
# ******
#
#  RT @ifernweh: เพิ่งรู้ว่าคลิป viral ตอนนั้นคือ biden ที่เป็นแคนดิเดตนายกอเมริกาในตอนนี้อะ แหะ ก็รู้ว่าแก่แล้วอะนะ แต่มาแตะต้องตัวผู้หญิงกับ…
# ...
